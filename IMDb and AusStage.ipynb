# %% [markdown]
# ## AusStage and IMDb

# %%
import pandas as pd

# %%
ausStage = pd.read_csv('AusStage_biography_level_selected_Top500EventProduction_202209211120.csv')
ausStage
# Out:
#       Unnamed: 0  original_id  original_id_unf_alsokwn prefix suffix  \
# 0          68024       433803                    71804    NaN    NaN
# 1          95944       458211                    94493    NaN    NaN
# 2         163448       529669                   162822    NaN    NaN
# 3         184141       550666                   183573    NaN    NaN
# 4         184393       550925                   183830    NaN    NaN
# ...          ...          ...                      ...    ...    ...
# 1042        5249         9786                     6751    NaN    NaN
# 1043        6877        10141                     7035    NaN    NaN
# 1044        2884         2642                     2715     Mr    NaN
# 1045        6534       203365                     7459    NaN    NaN
# 1046        2620         3469                     3439    NaN    NaN
#
#                          display_name first_name     middle_name  last_name  \
# ...

# %%
IMDb_names = pd.read_csv('IMDb.csv')
IMDb_names
# Out:
#           Unnamed: 0     nconst         primaryName birthYear deathYear  \
# 0                  0  nm0000001        Fred Astaire      1899      1987
# 1                  1  nm0000002       Lauren Bacall      1924      2014
# 2                  2  nm0000003     Brigitte Bardot      1934        \N
# 3                  3  nm0000004        John Belushi      1949      1982
# 4                  4  nm0000005      Ingmar Bergman      1918      2007
# ...              ...        ...                 ...       ...       ...
# 11952816    11952816  nm9993714   Romeo del Rosario        \N        \N
# 11952817    11952817  nm9993716       Essias Loberg        \N        \N
# 11952818    11952818  nm9993717  Harikrishnan Rajan        \N        \N
# 11952819    11952819  nm9993718         Aayush Nair        \N        \N
# 11952820    11952820  nm9993719          Andre Hill        \N        \N
#
#                             primaryProfession  \
# 0              soundtrack,actor,miscellaneous
# ...

# %%
common_data = ausStage.merge(IMDb_names, left_on='display_name', right_on='primaryName')
common_names.to_csv('merged.csv')

# %%
title_akas = pd.read_csv('IMDb datasets/title.akas.tsv', sep='\t')
title_akas
# Out:
# /var/folders/1f/h80p_db528d2k055yqcq1c080000gn/T/ipykernel_1639/2067273468.py:1: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   title_akas = pd.read_csv('IMDb datasets/title.akas.tsv', sep='\t')
#             titleId  ordering                      title region language  \
# 0         tt0000001         1                 Карменсіта     UA       \N
# 1         tt0000001         2                 Carmencita     DE       \N
# 2         tt0000001         3  Carmencita - spanyol tánc     HU       \N
# 3         tt0000001         4                 Καρμενσίτα     GR       \N
# 4         tt0000001         5                 Карменсита     RU       \N
# ...             ...       ...                        ...    ...      ...
# 33290530  tt9916852         5             Episódio #3.20     PT       pt
# 33290531  tt9916852         6             Episodio #3.20     IT       it
# ...

# %%
#title_basics = pd.read_csv('IMDb datasets/title.basics.tsv', sep='\t')
#title_basics.to_csv('title_basics')
# Out:
# /var/folders/1f/h80p_db528d2k055yqcq1c080000gn/T/ipykernel_1639/1424140170.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   title_basics = pd.read_csv('IMDb datasets/title.basics.tsv', sep='\t')
